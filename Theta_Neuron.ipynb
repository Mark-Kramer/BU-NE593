# %% [markdown]
# # First, consider the HH model.

# %% [markdown]
# ## ... in 2-dimensional phase space

# %% [markdown]
# Load the HH model.

# %%
import requests
url = "https://raw.githubusercontent.com/Mark-Kramer/BU-MA665-MA666/master/HH_functions.py"
response = requests.get(url)
exec(response.text)

# %% [markdown]
# Simulate the HH model with enough drive ($I0=10$) to create tonic spiking.

# %%
[V,m,h,n,t]=HH(10,100)

# %% [markdown]
# Plot a 2-dimensional projection of the phase space.

# %%
import matplotlib.pyplot as plt
plt.plot("something", "something")
plt.xlabel('something')
plt.ylabel('something')
plt.grid()

# %% [markdown]
# ## ... bifurcation?

# %% [markdown]
# Can you find the $I0$ corresponding to a bifurcation in the HH dynamics?

# %%
I0 = "something"

[V,m,h,n,t]=HH(I0,500)
plt.plot(t,V); plt.xlabel('Time [ms]'); plt.ylabel('Voltage [mV]'); plt.ylim([-80, 50])

# %% [markdown]
# # Theta neuron

# %%
import numpy as np
import matplotlib.pyplot as plt

a       = "something"
dt      = 0.01
theta   = np.zeros([10000,1])
theta[0]= np.pi/4;

for k in range(0,10000-1):
    theta[k+1] = "something"

plt.figure()
plt.plot(t,np.mod(theta, 2*np.pi)-np.pi, '.')
plt.xlabel('Time')
plt.ylabel('Theta')
plt.grid()
plt.show()
